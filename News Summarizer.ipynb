# %%
import bs4 
import html5lib
import requests

# %%
response= requests.get(r"https://www.vox.com/policy-and-politics/2019/5/30/18642535/california-ab5-misclassify-employees-contractors")

# %%
type(response.text)
# Out:
# str

# %%
type(response.content)
# Out:
# bytes

# %%
content=response.content

# %%
soup=bs4.BeautifulSoup(content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
#     <title>California AB5: State Assembly passes employee misclassification bill - Vox</title>
#     <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#     <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#     <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#     <meta content="Vox" name="apple-mobile-web-app-title"/>
#
#
#     <script src="https://optimize-stats.voxmedia.com/loader.min.js?key=beb6b278a131e3b9" type="text/javascript"></script>
#       <meta content="https://www.facebook.com/Vox" property="article:publisher"/>
#   <meta content="Alexia Fernández Campbell" property="author"/>
#   <meta content="2019-05-30T13:10:00-04:00" property="article:published_time"/>
#   <meta content="2019-05-30T13:10:00-04:00" property="article:modified_time"/>
#
#
#
#
# ...

# %%
paras=soup.find_all('p')

# %%
for para in paras:
    print(para.text,"/n/n***********************************************************************************************************************************************************")
# Out:
# The state Assembly just passed a bill that could give Uber and Lyft drivers basic labor protections for the first time. /n/n***********************************************************************************************************************************************************
# California just took a major step in rewriting the rules of the gig economy. /n/n***********************************************************************************************************************************************************
# The state Assembly passed a bill Wednesday that would make it harder for companies to label workers as independent contractors instead of employees, a common practice that has allowed businesses to skirt state and federal labor laws. The bill will now go to the state Senate. /n/n***********************************************************************************************************************************************************
# ...

# %%
news=''
for para in paras:
    news += para.text

# %%
news
# Out:
# 'The state Assembly just passed a bill that could give Uber and Lyft drivers basic labor protections for the first time.California just took a major step in rewriting the rules of the gig economy.The state Assembly passed a bill Wednesday that would make it harder for companies to label workers as independent contractors instead of employees, a common practice that has allowed businesses to skirt state and federal labor laws. The bill will now go to the state Senate.Hundreds of thousands of independent contractors in California, ranging from Uber and Amazon drivers to manicurists and exotic dancers, would likely become employees under the bill. That small status change is huge. These workers would suddenly get labor protections and benefits that all employees get, such as unemployment insurance, health care subsidies, paid parental leave, overtime pay, workers’ compensation, and a guaranteed $12 minimum hourly wage. It also means companies are fuming about the added cost.The Californ
# ...

# %%
title=soup.find_all('title')[0].text

# %%
title
# Out:
# 'California AB5: State Assembly passes employee misclassification bill - Vox'

# %%
len(news.split())
# Out:
# 1668

# %%
import gensim

# %%
from gensim.summarization.summarizer import summarize
from gensim.summarization import keywords

# %%
summary=summarize(news, word_count=500)

# %%
print(f'A 500 words summary of the news article titled {title} is:\n')
print(summary)
# Out:
# A 500 words summary of the news article titled California AB5: State Assembly passes employee misclassification bill - Vox is:
#
# The state Assembly just passed a bill that could give Uber and Lyft drivers basic labor protections for the first time.California just took a major step in rewriting the rules of the gig economy.The state Assembly passed a bill Wednesday that would make it harder for companies to label workers as independent contractors instead of employees, a common practice that has allowed businesses to skirt state and federal labor laws.
# These workers would suddenly get labor protections and benefits that all employees get, such as unemployment insurance, health care subsidies, paid parental leave, overtime pay, workers’ compensation, and a guaranteed $12 minimum hourly wage.
# ...

# %%
len(summary.split())
# Out:
# 482

# %%
print("Keywords pertaining to this news article are: \n ")
print(keywords(news, ratio=0.1, lemmatize=True))
# Out:
# Keywords pertaining to this news article are:
#
# drivers
# courts
# labor
# tax
# california
# uber
# worker
# stated
# contractor
# business
# federation
# including
# benefit
# law
# assembly
# financial
# employee
# misclassifying
# competitive
# years
# costs
# company
# misclassification
# people
# economy
# employment
# called
# department
# minimum
# working
# accountability
# status
